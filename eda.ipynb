# %%
import pandas as pd

# Load cleaned data
df = pd.read_csv("data/processed/clean_csv")

from transform.feature_engineering import create_realistic_churn

df = create_realistic_churn(df)
df.to_csv("data/processed/final_churn_data.csv", index=False)

# Run EDA
from EDA.eda import run_eda

run_eda(df)
# Out:
# ...
# 🚀 STARTING EDA
# ...
#
# 📊 CUSTOMER BEHAVIOR
#
# Churn Percentage:
#  churn
# No     66.952553
# Yes    33.047447
# Name: proportion, dtype: float64
#
# Churn by Contract Type (%):
#  churn                  No        Yes
# contract_type
# Month-To-Month  49.301746  50.698254
# One Year        74.022152  25.977848
# Two Year        87.519367  12.480633
# Unknown         74.111261  25.888739
#
# Average Tenure by Churn:
#  churn
# No     32.252619
# Yes    25.433054
# Name: tenure, dtype: float64
#
# Average Monthly Charges by Churn:
#  churn
# No     76.315015
# Yes    87.566238
# Name: monthly_charges, dtype: float64
#
#
# 👥 DEMOGRAPHICS
#
# Churn by Gender (%):
#  churn           No        Yes
# gender
# Female   66.966465  33.033535
# Male     67.025453  32.974547
# Unknown  66.796312  33.203688
#
# Churn by Age Group (%):
#  churn             No        Yes
# age_group
# Young      66.750143  33.249857
# Adult      66.898006  33.101994
# Mid-Age    67.047572  32.952428
# ...
