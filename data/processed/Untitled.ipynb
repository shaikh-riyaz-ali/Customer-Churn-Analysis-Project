# %%
import pandas as pd

# %%
df = pd.read_csv("clean_csv")

# %%
df.shape
# Out:
# (95959, 11)

# %%
df.sample(10)
# Out:
#        customer_id   gender  age  tenure  monthly_charges  total_charges  \
# 44233        54808   Female   30      58           123.56        9310.54
# 90675        74148     Male   63      55           144.23        7605.63
# 1806         29975     Male   42      15            76.67        2330.20
# 39907        91912   Female   27      43            44.34        3762.76
# 68087        95571   Female   47      56            23.35        3653.69
# 41869        70341   Female   27      51            50.93        1525.24
# 65294        72533   Female   68       4            18.77        7443.02
# 41442        62960     Male   31      35           105.37        3749.03
# 44193        39992  Unknown   23      52            89.31        3007.59
# 72065        46669   Female   35      28            23.35        8674.24
#
#         contract_type payment_method internet_service churn  \
# 44233        Two Year        Unknown       No Service   Yes
# 90675        Two Year    Net Banking      Fiber Optic    No
# 1806   Month-To-Month     Debit Card              Dsl    No
# 39907        Two Year            Upi       No Service   Yes
# 68087        One Year     Debit Card       No Service    No
# 41869        Two Year        Unknown       No Service    No
# 65294        One Year        Unknown       No Service   Yes
# 41442  Month-To-Month     Debit Card       No Service   Yes
# 44193        Two Year            Upi       No Service    No
# 72065         Unknown     Debit Card      Fiber Optic   Yes
#
#                       signup_date
# 44233  2021-10-30 00:00:00.000000
# 90675  2020-05-26 00:00:00.000000
# 1806   2022-06-09 00:00:00.000000
# 39907  2021-09-02 00:00:00.000000
# 68087  2022-08-21 00:00:00.000000
# 41869  2020-11-25 00:00:00.000000
# 65294  2023-01-17 00:00:00.000000
# 41442  2022-05-31 00:00:00.000000
# 44193  2022-08-12 00:00:00.000000
# 72065  2021-10-01 00:00:00.000000

# %%
df['churn'] = df['churn'].replace({"False":"No","True":"Yes"})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 95959 entries, 0 to 95958
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       95959 non-null  int64
#  1   gender            95959 non-null  str
#  2   age               95959 non-null  int64
#  3   tenure            95959 non-null  int64
#  4   monthly_charges   95959 non-null  float64
#  5   total_charges     95959 non-null  float64
#  6   contract_type     95959 non-null  str
#  7   payment_method    95959 non-null  str
#  8   internet_service  95959 non-null  str
#  9   churn             95959 non-null  str
#  10  signup_date       95959 non-null  str
# dtypes: float64(2), int64(3), str(6)
# memory usage: 8.1 MB

# %%
df = pd.read_csv("final_churn_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = pd.read_csv("final_churn_data.csv")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'final_churn_data.csv'

# %%
df.shape

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 95959 entries, 0 to 95958
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       95959 non-null  int64
#  1   gender            95959 non-null  str
#  2   age               95959 non-null  int64
#  3   tenure            95959 non-null  int64
#  4   monthly_charges   95959 non-null  float64
#  5   total_charges     95959 non-null  float64
#  6   contract_type     95959 non-null  str
#  7   payment_method    95959 non-null  str
#  8   internet_service  95959 non-null  str
#  9   churn             95959 non-null  str
#  10  signup_date       94020 non-null  str
# dtypes: float64(2), int64(3), str(6)
# memory usage: 8.1 MB
