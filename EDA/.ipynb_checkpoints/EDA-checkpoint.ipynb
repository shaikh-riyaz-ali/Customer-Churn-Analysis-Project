# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"D:\customer chrun\data\processed\clean_csv")

# %%
df.shape
# Out:
# (95959, 11)

# %%
df.head()
# Out:
#    customer_id   gender   age  tenure  monthly_charges  total_charges  \
# 0      25795.0   Female  52.0    29.0            39.38        3778.23
# 1      10860.0   Female  63.0     1.0           146.06         939.51
# 2      86820.0   Female  68.0    31.0            22.21        8791.31
# 3      64886.0     Male  60.0    19.0           115.98        7733.63
# 4      16265.0  Unknown  24.0    44.0           133.84        2834.76
#
#     contract_type payment_method internet_service  churn signup_date
# 0         Unknown     Debit Card       No Service     No  2022-09-18
# 1  Month-To-Month    Net Banking      Fiber Optic     No  2022-05-29
# 2        One Year    Net Banking              Dsl  False  2023-05-04
# 3  Month-To-Month    Net Banking      Fiber Optic   True  2024-02-15
# 4        One Year            Upi       No Service   True  2022-12-08

# %%
df['churn'].unique()
# Out:
# <StringArray>
# ['No', 'False', 'True', 'Yes']
# Length: 4, dtype: str

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male', 'Unknown']
# Length: 3, dtype: str

# %%
df['contract_type'].unique()
# Out:
# <StringArray>
# ['Unknown', 'Month-To-Month', 'One Year', 'Two Year']
# Length: 4, dtype: str

# %%
df['internet_service'].unique()
# Out:
# <StringArray>
# ['No Service', 'Fiber Optic', 'Dsl']
# Length: 3, dtype: str

# %%
df['signup_date'].unique()
# Out:
# <StringArray>
# ['2022-09-18', '2022-05-29', '2023-05-04', '2024-02-15', '2022-12-08',
#  '2021-02-16', '2022-04-26', '2020-06-13', '2022-12-22', '2020-12-13',
#  ...
#  '2020-02-06', '2024-09-30', '2020-11-06', '2021-06-12', '2021-11-02',
#  '2023-06-27', '2023-03-17', '2021-10-29', '2021-08-25', '2022-07-03']
# Length: 1829, dtype: str
