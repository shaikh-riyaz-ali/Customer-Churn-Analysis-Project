# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"D:\customer chrun\data\processed\clean_csv")

# %%
df.shape
# Out:
# (95959, 11)

# %%
df.sample(10)
# Out:
#        customer_id   gender  age  tenure  monthly_charges  total_charges  \
# 85826        76076     Male   41      16           140.21        6422.76
# 2764         21116   Female   24      22            97.18        9079.43
# 81701        49007  Unknown   25       2           138.23        5036.04
# 13127        51335  Unknown   28      18            20.10        7525.17
# 74649        28026   Female   23      32            99.77        1856.20
# 77325        43318   Female   41      28            92.47        1380.79
# 26508        57128     Male   33      22            52.73        2764.69
# 74337        90226  Unknown   65      18            30.85        9788.87
# 86686        16816   Female   27      30            90.20        8070.33
# 19743        27332  Unknown   48      53            45.00        9781.22
#
#         contract_type payment_method internet_service churn signup_date
# 85826  Month-To-Month        Unknown      Fiber Optic   Yes  2022-05-15
# ...

# %%
df['churn'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male', 'Unknown']
# Length: 3, dtype: str

# %%
df['contract_type'].unique()
# Out:
# <StringArray>
# ['Unknown', 'Month-To-Month', 'One Year', 'Two Year']
# Length: 4, dtype: str

# %%
df['internet_service'].unique()
# Out:
# <StringArray>
# ['No Service', 'Fiber Optic', 'Dsl']
# Length: 3, dtype: str

# %%
df['signup_date'].unique()
# Out:
# <StringArray>
# ['2022-09-18', '2022-05-29', '2023-05-04', '2024-02-15', '2022-12-08',
#  '2021-02-16', '2022-04-26', '2020-06-13', '2022-12-22', '2020-12-13',
#  ...
#  '2020-02-06', '2024-09-30', '2020-11-06', '2021-06-12', '2021-11-02',
#  '2023-06-27', '2023-03-17', '2021-10-29', '2021-08-25', '2022-07-03']
# Length: 1829, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 95959 entries, 0 to 95958
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       95959 non-null  int64
#  1   gender            95959 non-null  str
#  2   age               95959 non-null  int64
#  3   tenure            95959 non-null  int64
#  4   monthly_charges   95959 non-null  float64
#  5   total_charges     95959 non-null  float64
#  6   contract_type     95959 non-null  str
#  7   payment_method    95959 non-null  str
#  8   internet_service  95959 non-null  str
#  9   churn             95959 non-null  str
#  10  signup_date       94020 non-null  str
# dtypes: float64(2), int64(3), str(6)
# memory usage: 8.1 MB
